# %%
import h5py
import numpy as np
import matplotlib.pyplot as plt

import matplotlib
matplotlib.rcParams["figure.dpi"] = 600

# %%
dataset_dir = "datasets\FEMNIST_by_write\write_all_labels.hdf5"
binary_data_file = h5py.File(dataset_dir, "r")

writers = sorted(binary_data_file.keys())

# %%
img_count_by_wirter = []
count_each_label =[0]*62
count_covered_class = [0]*63

for writer in writers:
    images = binary_data_file[writer]['images']
    labels = binary_data_file[writer]['labels']
    img_count_by_wirter.append(images.shape[0])
    count_covered_class[len(np.unique(labels))] += 1
    for l in labels:
        count_each_label[l] += 1

# %%
colors = []
colors.extend(["red"]*10)
colors.extend(["green"]*26)
colors.extend(["blue"]*26)

fig, ax = plt.subplots(figsize=(10, 5))
ax.bar(range(len(count_each_label)), count_each_label, color=colors)
ax.set_xlabel('Classes')
ax.set_ylabel('Number of each class')
# ax.set_title('Count all classes')
plt.margins(x=0.02)

legend_colors = {'0-9 (0-9)':'red', 'A-Z (10-35)':'green', 'a-z (36-61)':'blue'}         
legend_labels = list(legend_colors.keys())
handles = [plt.Rectangle((0,0),1,1, color=legend_colors[label]) for label in legend_labels]
plt.legend(handles, legend_labels)

fig.show()
# Out:
# D:\SSD_Optimization\TEMP_FILES\TEMP\ipykernel_16108\1062575161.py:18: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
fig, ax = plt.subplots(figsize=(10, 5))
ax.bar(range(len(count_covered_class)), count_covered_class, color='r')
ax.set_xlabel('Number of covered classes')
ax.set_ylabel('Number of clients')
# ax.set_title('Clients covered classes')
plt.margins(x=0.02)

fig.show()
# Out:
# D:\SSD_Optimization\TEMP_FILES\TEMP\ipykernel_16108\4012681367.py:8: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
fig, ax = plt.subplots(figsize=(10, 5))
# ax.hist(img_count_by_wirter, bins=100, color='r')
ax.hist(img_count_by_wirter, bins=100, rwidth=0.8, color='green')
ax.set_xlabel('Number of images')
ax.set_ylabel('Number of clients')
# ax.set_title('Clients images')

fig.show()
# Out:
# D:\SSD_Optimization\TEMP_FILES\TEMP\ipykernel_16108\491873338.py:8: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
