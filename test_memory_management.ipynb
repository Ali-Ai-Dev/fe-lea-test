# %%
import tensorflow as tf # same issue with tf-nightly = "2.15.0.dev20230904"
import time
import gc
import psutil # psutil == "5.9.5"
import subprocess as sp

# %%
def get_cpu_memory():
    memory_info = psutil.virtual_memory()
    # you can have the percentage of used RAM
    memory_percent = 100.0 - memory_info.percent
    memory_free_values = memory_info.available / (1024 * 1024)  # in MB
    # you can calculate percentage of available memory
    return memory_free_values, memory_percent

class MyModel(tf.keras.Model):

    def __init__(self):
        super().__init__()
        self.dense1 = tf.keras.layers.Dense(1000, activation=tf.nn.relu)
        self.dense2 = tf.keras.layers.Dense(10000, activation=tf.nn.relu)
        self.dense3 = tf.keras.layers.Dense(10000, activation=tf.nn.relu)
        self.dense4 = tf.keras.layers.Dense(1000, activation=tf.nn.softmax)

    def call(self, inputs):
        x = self.dense1(inputs)
        x = self.dense2(x)
        x = self.dense3(x)
        x = self.dense4(x)
        return x


if __name__ == '__main__':
    print(f"Starting..")
    memory_free_val_initial, memory_perc_initial = get_cpu_memory()
    print(f"[Memory monitoring] Free memory CPU {memory_free_val_initial} MB, {memory_perc_initial} %.")

    for r in range(0, 10):
        with tf.device("/cpu:0"):
            model = MyModel()
            # ds = tf.data.Dataset.from_tensor_slices((tf.random.uniform((64*4, 1000)), tf.ones((64*4))))
            # ds = (lambda: tf.data.Dataset.from_tensor_slices((tf.random.uniform((64 * 20, 1000)), tf.ones((64 * 20)))))
            x_train = tf.random.uniform((64, 1000))
            y_train = tf.ones((64))
            model.compile(optimizer='sgd', loss=tf.keras.losses.SparseCategoricalCrossentropy())

            # model.fit(ds().batch(64), verbose=0)
            # model.evaluate(ds().batch(64), verbose=0)
            model.fit(x_train, y_train, batch_size=64, verbose=0)
            model.evaluate(x_train, y_train, batch_size=64, verbose=0)
            

            if r % 1 == 0:
                # print every 5 model.fit
                print(f"Round: {r}")
                memory_free_val, memory_perc = get_cpu_memory()
                print(f"[Memory monitoring] Free memory CPU {memory_free_val} MB, {memory_perc} %.")
                memory_free_first = memory_free_val

            
            # tf.keras.backend.clear_session()
            # gc.collect()
            # del model
            # del x_train
            # del y_train

    print(f"[Memory monitoring CPU] Memory usage increased by {memory_free_first - memory_free_val} MB, "
          "during the process.")
# Out:
# Starting..
# [Memory monitoring] Free memory CPU 7312.828125 MB, 60.1 %.
# Round: 0
# [Memory monitoring] Free memory CPU 6291.24609375 MB, 51.7 %.
# Round: 1
# [Memory monitoring] Free memory CPU 5760.2578125 MB, 47.3 %.
# Round: 2
# [Memory monitoring] Free memory CPU 5760.15234375 MB, 47.3 %.
# Round: 3
# [Memory monitoring] Free memory CPU 5755.48046875 MB, 47.3 %.
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_train_function.<locals>.train_function at 0x000001E1D1244CA0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_test_function.<locals>.test_function at 0x000001E1D1245360> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Round: 4
# [Memory monitoring] Free memory CPU 4663.56640625 MB, 38.3 %.
# WARNING:tensorflow:6 out of the last 6 calls to <function Model.make_train_function.<locals>.train_function at 0x000001E1D2B14670> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 6 calls to <function Model.make_test_function.<locals>.test_function at 0x000001E1D2B15630> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Round: 5
# [Memory monitoring] Free memory CPU 4659.0703125 MB, 38.3 %.
# Round: 6
# [Memory monitoring] Free memory CPU 2541.53515625 MB, 20.900000000000006 %.
# Round: 7
# [Memory monitoring] Free memory CPU 2513.04296875 MB, 20.599999999999994 %.
# Round: 8
# [Memory monitoring] Free memory CPU 2507.625 MB, 20.599999999999994 %.
# Round: 9
# [Memory monitoring] Free memory CPU 2570.234375 MB, 21.099999999999994 %.
# [Memory monitoring CPU] Memory usage increased by 0.0 MB, during the process.

# %%
def get_cpu_memory():
    memory_info = psutil.virtual_memory()
    # you can have the percentage of used RAM
    memory_percent = 100.0 - memory_info.percent
    memory_free_values = memory_info.available / (1024 * 1024)  # in MB
    # you can calculate percentage of available memory
    return memory_free_values, memory_percent

class MyModel(tf.keras.Model):

    def __init__(self):
        super().__init__()
        self.dense1 = tf.keras.layers.Dense(1000, activation=tf.nn.relu)
        self.dense2 = tf.keras.layers.Dense(10000, activation=tf.nn.relu)
        self.dense3 = tf.keras.layers.Dense(10000, activation=tf.nn.relu)
        self.dense4 = tf.keras.layers.Dense(1000, activation=tf.nn.softmax)

    def call(self, inputs):
        x = self.dense1(inputs)
        x = self.dense2(x)
        x = self.dense3(x)
        x = self.dense4(x)
        return x


if __name__ == '__main__':
    print(f"Starting..")
    memory_free_val_initial, memory_perc_initial = get_cpu_memory()
    print(f"[Memory monitoring] Free memory CPU {memory_free_val_initial} MB, {memory_perc_initial} %.")

    for r in range(0, 10):
        with tf.device("/cpu:0"):
            model = MyModel()
            # ds = tf.data.Dataset.from_tensor_slices((tf.random.uniform((64*4, 1000)), tf.ones((64*4))))
            # ds = (lambda: tf.data.Dataset.from_tensor_slices((tf.random.uniform((64 * 20, 1000)), tf.ones((64 * 20)))))
            x_train = tf.random.uniform((64, 1000))
            y_train = tf.ones((64))
            model.compile(optimizer='sgd', loss=tf.keras.losses.SparseCategoricalCrossentropy())

            # model.fit(ds().batch(64), verbose=0)
            # model.evaluate(ds().batch(64), verbose=0)
            model.fit(x_train, y_train, batch_size=64, verbose=0)
            model.evaluate(x_train, y_train, batch_size=64, verbose=0)
            

            if r % 1 == 0:
                # print every 5 model.fit
                print(f"Round: {r}")
                memory_free_val, memory_perc = get_cpu_memory()
                print(f"[Memory monitoring] Free memory CPU {memory_free_val} MB, {memory_perc} %.")
                memory_free_first = memory_free_val

            
            tf.keras.backend.clear_session()
            # gc.collect()
            # del model
            # del x_train
            # del y_train

    print(f"[Memory monitoring CPU] Memory usage increased by {memory_free_first - memory_free_val} MB, "
          "during the process.")
# Out:
# Starting..
# [Memory monitoring] Free memory CPU 7583.66015625 MB, 62.3 %.
# Round: 0
# [Memory monitoring] Free memory CPU 6535.3359375 MB, 53.7 %.
# Round: 1
# [Memory monitoring] Free memory CPU 5994.890625 MB, 49.2 %.
# Round: 2
# [Memory monitoring] Free memory CPU 5993.609375 MB, 49.2 %.
# Round: 3
# [Memory monitoring] Free memory CPU 5992.375 MB, 49.2 %.
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_train_function.<locals>.train_function at 0x000001B5948F8820> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_test_function.<locals>.test_function at 0x000001B58F9A2F80> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Round: 4
# [Memory monitoring] Free memory CPU 4914.296875 MB, 40.4 %.
# WARNING:tensorflow:6 out of the last 6 calls to <function Model.make_train_function.<locals>.train_function at 0x000001B594A78E50> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 6 calls to <function Model.make_test_function.<locals>.test_function at 0x000001B594A795A0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Round: 5
# [Memory monitoring] Free memory CPU 4895.859375 MB, 40.2 %.
# Round: 6
# [Memory monitoring] Free memory CPU 2760.84375 MB, 22.700000000000003 %.
# Round: 7
# [Memory monitoring] Free memory CPU 2870.81640625 MB, 23.599999999999994 %.
# Round: 8
# [Memory monitoring] Free memory CPU 2888.453125 MB, 23.700000000000003 %.
# Round: 9
# [Memory monitoring] Free memory CPU 2859.61328125 MB, 23.5 %.
# [Memory monitoring CPU] Memory usage increased by 0.0 MB, during the process.

# %%
def get_cpu_memory():
    memory_info = psutil.virtual_memory()
    # you can have the percentage of used RAM
    memory_percent = 100.0 - memory_info.percent
    memory_free_values = memory_info.available / (1024 * 1024)  # in MB
    # you can calculate percentage of available memory
    return memory_free_values, memory_percent

class MyModel(tf.keras.Model):

    def __init__(self):
        super().__init__()
        self.dense1 = tf.keras.layers.Dense(1000, activation=tf.nn.relu)
        self.dense2 = tf.keras.layers.Dense(10000, activation=tf.nn.relu)
        self.dense3 = tf.keras.layers.Dense(10000, activation=tf.nn.relu)
        self.dense4 = tf.keras.layers.Dense(1000, activation=tf.nn.softmax)

    def call(self, inputs):
        x = self.dense1(inputs)
        x = self.dense2(x)
        x = self.dense3(x)
        x = self.dense4(x)
        return x


if __name__ == '__main__':
    print(f"Starting..")
    memory_free_val_initial, memory_perc_initial = get_cpu_memory()
    print(f"[Memory monitoring] Free memory CPU {memory_free_val_initial} MB, {memory_perc_initial} %.")

    for r in range(0, 20):
        with tf.device("/cpu:0"):
            model = MyModel()
            # ds = tf.data.Dataset.from_tensor_slices((tf.random.uniform((64*4, 1000)), tf.ones((64*4))))
            # ds = (lambda: tf.data.Dataset.from_tensor_slices((tf.random.uniform((64 * 20, 1000)), tf.ones((64 * 20)))))
            x_train = tf.random.uniform((64, 1000))
            y_train = tf.ones((64))
            model.compile(optimizer='sgd', loss=tf.keras.losses.SparseCategoricalCrossentropy())

            # model.fit(ds().batch(64), verbose=0)
            # model.evaluate(ds().batch(64), verbose=0)
            model.fit(x_train, y_train, batch_size=64, verbose=0)
            model.evaluate(x_train, y_train, batch_size=64, verbose=0)
            

            if r % 1 == 0:
                # print every 5 model.fit
                print(f"Round: {r}")
                memory_free_val, memory_perc = get_cpu_memory()
                print(f"[Memory monitoring] Free memory CPU {memory_free_val} MB, {memory_perc} %.")
                memory_free_first = memory_free_val

            
            # tf.keras.backend.clear_session()
            gc.collect()
            # del model
            # del x_train
            # del y_train

    print(f"[Memory monitoring CPU] Memory usage increased by {memory_free_first - memory_free_val} MB, "
          "during the process.")
# Out:
# Starting..
# [Memory monitoring] Free memory CPU 7529.97265625 MB, 61.8 %.
# Round: 0
# [Memory monitoring] Free memory CPU 6487.203125 MB, 53.3 %.
# Round: 1
# [Memory monitoring] Free memory CPU 5949.56640625 MB, 48.9 %.
# Round: 2
# [Memory monitoring] Free memory CPU 5950.109375 MB, 48.9 %.
# Round: 3
# [Memory monitoring] Free memory CPU 5938.8984375 MB, 48.8 %.
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_train_function.<locals>.train_function at 0x00000151DB872F80> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_test_function.<locals>.test_function at 0x00000151E4284B80> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Round: 4
# [Memory monitoring] Free memory CPU 5926.40625 MB, 48.7 %.
# WARNING:tensorflow:6 out of the last 6 calls to <function Model.make_train_function.<locals>.train_function at 0x00000151C6772200> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 6 calls to <function Model.make_test_function.<locals>.test_function at 0x00000151DB8349D0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Round: 5
# [Memory monitoring] Free memory CPU 5919.48046875 MB, 48.6 %.
# Round: 6
# [Memory monitoring] Free memory CPU 5939.2421875 MB, 48.8 %.
# Round: 7
# [Memory monitoring] Free memory CPU 5943.125 MB, 48.8 %.
# Round: 8
# [Memory monitoring] Free memory CPU 5943.3984375 MB, 48.8 %.
# Round: 9
# [Memory monitoring] Free memory CPU 5933.140625 MB, 48.7 %.
# Round: 10
# [Memory monitoring] Free memory CPU 5953.8203125 MB, 48.9 %.
# Round: 11
# [Memory monitoring] Free memory CPU 5942.09375 MB, 48.8 %.
# Round: 12
# [Memory monitoring] Free memory CPU 5941.32421875 MB, 48.8 %.
# Round: 13
# [Memory monitoring] Free memory CPU 5920.73046875 MB, 48.6 %.
# Round: 14
# [Memory monitoring] Free memory CPU 5930.58984375 MB, 48.7 %.
# Round: 15
# [Memory monitoring] Free memory CPU 5935.203125 MB, 48.7 %.
# Round: 16
# [Memory monitoring] Free memory CPU 5937.5859375 MB, 48.8 %.
# Round: 17
# [Memory monitoring] Free memory CPU 5935.546875 MB, 48.7 %.
# Round: 18
# [Memory monitoring] Free memory CPU 5929.03515625 MB, 48.7 %.
# Round: 19
# [Memory monitoring] Free memory CPU 5937.25390625 MB, 48.8 %.
# [Memory monitoring CPU] Memory usage increased by 0.0 MB, during the process.

# %%
def get_cpu_memory():
    memory_info = psutil.virtual_memory()
    # you can have the percentage of used RAM
    memory_percent = 100.0 - memory_info.percent
    memory_free_values = memory_info.available / (1024 * 1024)  # in MB
    # you can calculate percentage of available memory
    return memory_free_values, memory_percent

class MyModel(tf.keras.Model):

    def __init__(self):
        super().__init__()
        self.dense1 = tf.keras.layers.Dense(1000, activation=tf.nn.relu)
        self.dense2 = tf.keras.layers.Dense(10000, activation=tf.nn.relu)
        self.dense3 = tf.keras.layers.Dense(10000, activation=tf.nn.relu)
        self.dense4 = tf.keras.layers.Dense(1000, activation=tf.nn.softmax)

    def call(self, inputs):
        x = self.dense1(inputs)
        x = self.dense2(x)
        x = self.dense3(x)
        x = self.dense4(x)
        return x


if __name__ == '__main__':
    print(f"Starting..")
    memory_free_val_initial, memory_perc_initial = get_cpu_memory()
    print(f"[Memory monitoring] Free memory CPU {memory_free_val_initial} MB, {memory_perc_initial} %.")

    for r in range(0, 10):
        with tf.device("/cpu:0"):
            model = MyModel()
            # ds = tf.data.Dataset.from_tensor_slices((tf.random.uniform((64*4, 1000)), tf.ones((64*4))))
            # ds = (lambda: tf.data.Dataset.from_tensor_slices((tf.random.uniform((64 * 20, 1000)), tf.ones((64 * 20)))))
            x_train = tf.random.uniform((64, 1000))
            y_train = tf.ones((64))
            model.compile(optimizer='sgd', loss=tf.keras.losses.SparseCategoricalCrossentropy())

            # model.fit(ds().batch(64), verbose=0)
            # model.evaluate(ds().batch(64), verbose=0)
            model.fit(x_train, y_train, batch_size=64, verbose=0)
            model.evaluate(x_train, y_train, batch_size=64, verbose=0)
            

            if r % 1 == 0:
                # print every 5 model.fit
                print(f"Round: {r}")
                memory_free_val, memory_perc = get_cpu_memory()
                print(f"[Memory monitoring] Free memory CPU {memory_free_val} MB, {memory_perc} %.")
                memory_free_first = memory_free_val

            
            tf.keras.backend.clear_session()
            gc.collect()
            # del model
            # del x_train
            # del y_train

    print(f"[Memory monitoring CPU] Memory usage increased by {memory_free_first - memory_free_val} MB, "
          "during the process.")
# Out:
# Starting..
# [Memory monitoring] Free memory CPU 7689.921875 MB, 63.2 %.
# Round: 0
# [Memory monitoring] Free memory CPU 6656.45703125 MB, 54.7 %.
# Round: 1
# [Memory monitoring] Free memory CPU 6109.453125 MB, 50.2 %.
# Round: 2
# [Memory monitoring] Free memory CPU 6114.75390625 MB, 50.2 %.
# Round: 3
# [Memory monitoring] Free memory CPU 6110.7734375 MB, 50.2 %.
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_train_function.<locals>.train_function at 0x000001D50E101990> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_test_function.<locals>.test_function at 0x000001D52BB323B0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Round: 4
# [Memory monitoring] Free memory CPU 6104.1875 MB, 50.1 %.
# WARNING:tensorflow:6 out of the last 6 calls to <function Model.make_train_function.<locals>.train_function at 0x000001D50E101D80> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 6 calls to <function Model.make_test_function.<locals>.test_function at 0x000001D52BAF95A0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Round: 5
# [Memory monitoring] Free memory CPU 6103.58203125 MB, 50.1 %.
# Round: 6
# [Memory monitoring] Free memory CPU 6101.984375 MB, 50.1 %.
# Round: 7
# [Memory monitoring] Free memory CPU 6110.34765625 MB, 50.2 %.
# Round: 8
# [Memory monitoring] Free memory CPU 6119.8984375 MB, 50.3 %.
# Round: 9
# [Memory monitoring] Free memory CPU 6076.26953125 MB, 49.9 %.
# [Memory monitoring CPU] Memory usage increased by 0.0 MB, during the process.

# %%
def get_cpu_memory():
    memory_info = psutil.virtual_memory()
    # you can have the percentage of used RAM
    memory_percent = 100.0 - memory_info.percent
    memory_free_values = memory_info.available / (1024 * 1024)  # in MB
    # you can calculate percentage of available memory
    return memory_free_values, memory_percent

class MyModel(tf.keras.Model):

    def __init__(self):
        super().__init__()
        self.dense1 = tf.keras.layers.Dense(1000, activation=tf.nn.relu)
        self.dense2 = tf.keras.layers.Dense(10000, activation=tf.nn.relu)
        self.dense3 = tf.keras.layers.Dense(10000, activation=tf.nn.relu)
        self.dense4 = tf.keras.layers.Dense(1000, activation=tf.nn.softmax)

    def call(self, inputs):
        x = self.dense1(inputs)
        x = self.dense2(x)
        x = self.dense3(x)
        x = self.dense4(x)
        return x


if __name__ == '__main__':
    print(f"Starting..")
    memory_free_val_initial, memory_perc_initial = get_cpu_memory()
    print(f"[Memory monitoring] Free memory CPU {memory_free_val_initial} MB, {memory_perc_initial} %.")

    for r in range(0, 10):
        with tf.device("/cpu:0"):
            model = MyModel()
            # ds = tf.data.Dataset.from_tensor_slices((tf.random.uniform((64*4, 1000)), tf.ones((64*4))))
            # ds = (lambda: tf.data.Dataset.from_tensor_slices((tf.random.uniform((64 * 20, 1000)), tf.ones((64 * 20)))))
            x_train = tf.random.uniform((64, 1000))
            y_train = tf.ones((64))
            model.compile(optimizer='sgd', loss=tf.keras.losses.SparseCategoricalCrossentropy())

            # model.fit(ds().batch(64), verbose=0)
            # model.evaluate(ds().batch(64), verbose=0)
            model.fit(x_train, y_train, batch_size=64, verbose=0)
            model.evaluate(x_train, y_train, batch_size=64, verbose=0)
            

            if r % 1 == 0:
                # print every 5 model.fit
                print(f"Round: {r}")
                memory_free_val, memory_perc = get_cpu_memory()
                print(f"[Memory monitoring] Free memory CPU {memory_free_val} MB, {memory_perc} %.")
                memory_free_first = memory_free_val

            
            tf.keras.backend.clear_session()
            gc.collect()
            del model
            del x_train
            del y_train

    print(f"[Memory monitoring CPU] Memory usage increased by {memory_free_first - memory_free_val} MB, "
          "during the process.")
# Out:
# Starting..
# [Memory monitoring] Free memory CPU 7695.734375 MB, 63.2 %.
# Round: 0
# [Memory monitoring] Free memory CPU 6629.3671875 MB, 54.4 %.
# Round: 1
# [Memory monitoring] Free memory CPU 6646.55859375 MB, 54.6 %.
# Round: 2
# [Memory monitoring] Free memory CPU 6644.8828125 MB, 54.6 %.
# Round: 3
# [Memory monitoring] Free memory CPU 6621.94140625 MB, 54.4 %.
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_train_function.<locals>.train_function at 0x0000017C97D996C0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_test_function.<locals>.test_function at 0x0000017C97D99120> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Round: 4
# [Memory monitoring] Free memory CPU 6604.93359375 MB, 54.2 %.
# WARNING:tensorflow:6 out of the last 6 calls to <function Model.make_train_function.<locals>.train_function at 0x0000017C97D99990> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 6 calls to <function Model.make_test_function.<locals>.test_function at 0x0000017C97D99EA0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Round: 5
# [Memory monitoring] Free memory CPU 6605.30078125 MB, 54.2 %.
# Round: 6
# [Memory monitoring] Free memory CPU 6628.5234375 MB, 54.4 %.
# Round: 7
# [Memory monitoring] Free memory CPU 6628.25390625 MB, 54.4 %.
# Round: 8
# [Memory monitoring] Free memory CPU 6630.15625 MB, 54.4 %.
# Round: 9
# [Memory monitoring] Free memory CPU 6627.3359375 MB, 54.4 %.
# [Memory monitoring CPU] Memory usage increased by 0.0 MB, during the process.

# %%
def get_cpu_memory():
    memory_info = psutil.virtual_memory()
    # you can have the percentage of used RAM
    memory_percent = 100.0 - memory_info.percent
    memory_free_values = memory_info.available / (1024 * 1024)  # in MB
    # you can calculate percentage of available memory
    return memory_free_values, memory_percent

class MyModel(tf.keras.Model):

    def __init__(self):
        super().__init__()
        self.dense1 = tf.keras.layers.Dense(1000, activation=tf.nn.relu)
        self.dense2 = tf.keras.layers.Dense(10000, activation=tf.nn.relu)
        self.dense3 = tf.keras.layers.Dense(10000, activation=tf.nn.relu)
        self.dense4 = tf.keras.layers.Dense(1000, activation=tf.nn.softmax)

    def call(self, inputs):
        x = self.dense1(inputs)
        x = self.dense2(x)
        x = self.dense3(x)
        x = self.dense4(x)
        return x


if __name__ == '__main__':
    print(f"Starting..")
    memory_free_val_initial, memory_perc_initial = get_cpu_memory()
    print(f"[Memory monitoring] Free memory CPU {memory_free_val_initial} MB, {memory_perc_initial} %.")

    for r in range(0, 10):
        with tf.device("/cpu:0"):
            model = MyModel()
            # ds = tf.data.Dataset.from_tensor_slices((tf.random.uniform((64*4, 1000)), tf.ones((64*4))))
            # ds = (lambda: tf.data.Dataset.from_tensor_slices((tf.random.uniform((64 * 20, 1000)), tf.ones((64 * 20)))))
            x_train = tf.random.uniform((64, 1000))
            y_train = tf.ones((64))
            model.compile(optimizer='sgd', loss=tf.keras.losses.SparseCategoricalCrossentropy())

            # model.fit(ds().batch(64), verbose=0)
            # model.evaluate(ds().batch(64), verbose=0)
            model.fit(x_train, y_train, batch_size=64, verbose=0)
            model.evaluate(x_train, y_train, batch_size=64, verbose=0)
            

            if r % 1 == 0:
                # print every 5 model.fit
                print(f"Round: {r}")
                memory_free_val, memory_perc = get_cpu_memory()
                print(f"[Memory monitoring] Free memory CPU {memory_free_val} MB, {memory_perc} %.")
                memory_free_first = memory_free_val

            
            tf.keras.backend.clear_session()
            # gc.collect()
            del model
            del x_train
            del y_train

    print(f"[Memory monitoring CPU] Memory usage increased by {memory_free_first - memory_free_val} MB, "
          "during the process.")
# Out:
# Starting..
# [Memory monitoring] Free memory CPU 7650.16796875 MB, 62.8 %.
# Round: 0
# [Memory monitoring] Free memory CPU 6605.53125 MB, 54.2 %.
# Round: 1
# [Memory monitoring] Free memory CPU 6067.63671875 MB, 49.8 %.
# Round: 2
# [Memory monitoring] Free memory CPU 6071.015625 MB, 49.9 %.
# Round: 3
# [Memory monitoring] Free memory CPU 6064.1953125 MB, 49.8 %.
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_train_function.<locals>.train_function at 0x0000021FE6C08790> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_test_function.<locals>.test_function at 0x0000021FDF80EEF0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Round: 4
# [Memory monitoring] Free memory CPU 4988.74609375 MB, 41.0 %.
# WARNING:tensorflow:6 out of the last 6 calls to <function Model.make_train_function.<locals>.train_function at 0x0000021FE6FD5120> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 6 calls to <function Model.make_test_function.<locals>.test_function at 0x0000021FE6FD56C0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Round: 5
# [Memory monitoring] Free memory CPU 4990.18359375 MB, 41.0 %.
# Round: 6
# [Memory monitoring] Free memory CPU 2864.71484375 MB, 23.5 %.
# Round: 7
# [Memory monitoring] Free memory CPU 2952.171875 MB, 24.200000000000003 %.
# Round: 8
# [Memory monitoring] Free memory CPU 2962.94921875 MB, 24.299999999999997 %.
# Round: 9
# [Memory monitoring] Free memory CPU 2931.7265625 MB, 24.099999999999994 %.
# [Memory monitoring CPU] Memory usage increased by 0.0 MB, during the process.
